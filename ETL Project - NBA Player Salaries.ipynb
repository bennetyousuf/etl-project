# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_salaries = "/Users/bennetyousuf/Desktop/BCS/etl-project/Resources/salaries.csv" 
salaries_data_df = pd.read_csv(csv_salaries)
salaries_data_final = salaries_data_df.dropna()
salaries_data_final

#register value, seasons = whole nuumbers
#drop commas, $, . and convert to float; register/season/start = numeric
# Out:
#        Register Value         Player Name   Salary in $   Season Start  \
# 0                   1          A.C. Green        1750000          1990
# 1                 354          A.C. Green        1750000          1991
# 2                 727          A.C. Green        1750000          1992
# 3                1103          A.C. Green        1885000          1993
# 4                1497          A.C. Green        6472600          1994
# ...               ...                 ...            ...           ...
# 11832            6283  Zydrunas Ilgauskas        8740000          2005
# 11833            6658  Zydrunas Ilgauskas        9442697          2006
# 11834            7063  Zydrunas Ilgauskas       10142156          2007
# 11835            7485  Zydrunas Ilgauskas       10841615          2008
# 11836            7943  Zydrunas Ilgauskas       11541074          2009
#
#        Season End Team       Full Team Name
# 0            1991  LAL   Los Angeles Lakers
# ...

# %%
csv_titles = "/Users/bennetyousuf/Desktop/BCS/etl-project/Resources/titles.csv" 
titles_data_df = pd.read_csv(csv_titles)
titles_data_df.head()
# Out:
#    index  year    level         sport                   winner  \
# 0      1  1870  college  Football (M)         Princeton Tigers
# 1      2  1870  college  Football (M)  Rutgers Scarlet Knights
# 2      3  1871  college  Football (M)         Princeton Tigers
# 3      4  1873  college  Football (M)         Princeton Tigers
# 4      5  1874  college  Football (M)         Princeton Tigers
#
#         winner_metro runner_up runner_up_metro final_four3 final_four3_metro  \
# 0      Princeton, NJ       NaN             NaN         NaN               NaN
# 1  New Brunswick, NJ       NaN             NaN         NaN               NaN
# 2      Princeton, NJ       NaN             NaN         NaN               NaN
# 3      Princeton, NJ       NaN             NaN         NaN               NaN
# 4      Princeton, NJ       NaN             NaN         NaN               NaN
#
#   final_four4 final_four4_metro
# 0         NaN               NaN
# 1         NaN               NaN
# ...

# %%
titles_data_pro = titles_data_df.loc[titles_data_df["level"]=="pro"]
titles_data_sport = titles_data_pro.loc[titles_data_pro["sport"] == "NBA"]
titles_data_sport.dropna()
# Out:
#      index  year level sport                 winner  \
# 236    243  1947   pro   NBA  Philadelphia Warriors
# 244    251  1948   pro   NBA      Baltimore Bullets
# 252    259  1949   pro   NBA     Minneapolis Lakers
# 261    268  1950   pro   NBA     Minneapolis Lakers
# 268    275  1951   pro   NBA       Rochester Royals
# ..     ...   ...   ...   ...                    ...
# 939    949  2014   pro   NBA      San Antonio Spurs
# 952    962  2015   pro   NBA  Golden State Warriors
# 966    976  2016   pro   NBA    Cleveland Cavaliers
# 979    989  2017   pro   NBA  Golden State Warriors
# 993   1003  2018   pro   NBA  Golden State Warriors
#
#                    winner_metro              runner_up  \
# 236    Greater Philadelphia, PA          Chicago Stags
# 244               Baltimore, MD  Philadelphia Warriors
# 252             Twin Cities, MN    Washington Capitols
# 261             Twin Cities, MN     Syracuse Nationals
# 268               Rochester, NY        New York Knicks
# ...

# %%
#Create Connection 
rds_connection_string = "<postgres>:<postgres>@localhost:5432/player_db"
engine = create_engine(f'postgresql://{rds_connection_string}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-02b8c626fc56> in <module>
#       1 #Create Connection
#       2 rds_connection_string = "<postgres>:<postgres>@localhost:5432/player_db"
# ----> 3 engine = create_engine(f'postgresql://{rds_connection_string}')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/__init__.py in create_engine(*args, **kwargs)
#     518     strategy = kwargs.pop("strategy", default_strategy)
#     519     strategy = strategies.strategies[strategy]
# --> 520     return strategy.create(*args, **kwargs)
#     521
#     522
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
# ...
